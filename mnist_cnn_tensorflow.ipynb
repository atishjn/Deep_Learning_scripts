# %%
import tensorflow as tf

# Import MNIST data
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("MNIST_data/", one_hot=True)
# Out:
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
# Parameters
learning_rate = 0.001
training_iters = 200000
batch_size = 128
display_step = 10

# Network Parameters
n_input = 784 # MNIST data input (img shape: 28*28)
n_classes = 10 # MNIST total classes (0-9 digits)
dropout = 0.75 # Dropout, probability to keep units

# tf Graph input
x = tf.placeholder(tf.float32, [None, n_input])
y = tf.placeholder(tf.float32, [None, n_classes])
keep_prob = tf.placeholder(tf.float32) #dropout (keep probability)

# %%
# Create some wrappers for simplicity
def conv2d(x, W, b, strides=1):
    # Conv2D wrapper, with bias and relu activation
    x = tf.nn.conv2d(x, W, strides=[1, strides, strides, 1], padding='SAME')
    x = tf.nn.bias_add(x, b)
    return tf.nn.relu(x)


def maxpool2d(x, k=2):
    # MaxPool2D wrapper
    return tf.nn.max_pool(x, ksize=[1, k, k, 1], strides=[1, k, k, 1],
                          padding='SAME')


# Create model
def conv_net(x, weights, biases, dropout):
    # Reshape input picture
    x = tf.reshape(x, shape=[-1, 28, 28, 1])

    # Convolution Layer
    conv1 = conv2d(x, weights['wc1'], biases['bc1'])
    # Max Pooling (down-sampling)
    conv1 = maxpool2d(conv1, k=2)

    # Convolution Layer
    conv2 = conv2d(conv1, weights['wc2'], biases['bc2'])
    # Max Pooling (down-sampling)
    conv2 = maxpool2d(conv2, k=2)

    # Fully connected layer
    # Reshape conv2 output to fit fully connected layer input
    fc1 = tf.reshape(conv2, [-1, weights['wd1'].get_shape().as_list()[0]])
    fc1 = tf.add(tf.matmul(fc1, weights['wd1']), biases['bd1'])
    fc1 = tf.nn.relu(fc1)
    # Apply Dropout
    fc1 = tf.nn.dropout(fc1, dropout)

    # Output, class prediction
    out = tf.add(tf.matmul(fc1, weights['out']), biases['out'])
    return out

# %%
# Store layers weight & bias
weights = {
    # 5x5 conv, 1 input, 32 outputs
    'wc1': tf.Variable(tf.random_normal([5, 5, 1, 32])),
    # 5x5 conv, 32 inputs, 64 outputs
    'wc2': tf.Variable(tf.random_normal([5, 5, 32, 64])),
    # fully connected, 7*7*64 inputs, 1024 outputs
    'wd1': tf.Variable(tf.random_normal([7*7*64, 1024])),
    # 1024 inputs, 10 outputs (class prediction)
    'out': tf.Variable(tf.random_normal([1024, n_classes]))
}

biases = {
    'bc1': tf.Variable(tf.random_normal([32])),
    'bc2': tf.Variable(tf.random_normal([64])),
    'bd1': tf.Variable(tf.random_normal([1024])),
    'out': tf.Variable(tf.random_normal([n_classes]))
}

# Construct model
pred = conv_net(x, weights, biases, keep_prob)

# Define loss and optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=pred, labels=y))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

# Evaluate model
correct_pred = tf.equal(tf.argmax(pred, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# Initializing the variables
init = tf.global_variables_initializer()
# Out:
# WARNING:tensorflow:From <ipython-input-5-29b5db531a24>:24: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.

# %%
# Launch the graph
with tf.Session() as sess:
    sess.run(init)
    step = 1
    # Keep training until reach max iterations
    while step * batch_size < training_iters:
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        # Run optimization op (backprop)
        sess.run(optimizer, feed_dict={x: batch_x, y: batch_y,
                                       keep_prob: dropout})
        if step % display_step == 0:
            # Calculate batch loss and accuracy
            loss, acc = sess.run([cost, accuracy], feed_dict={x: batch_x,
                                                              y: batch_y,
                                                              keep_prob: 1.})
            print ("Iter " + str(step*batch_size) + ", Minibatch Loss= " + \
                  "{:.6f}".format(loss) + ", Training Accuracy= " + \
                  "{:.5f}".format(acc))
        step += 1
    print ("Optimization Finished!")

    # Calculate accuracy for 256 mnist test images
    print ("Testing Accuracy:", \
        sess.run(accuracy, feed_dict={x: mnist.test.images[:256],
                                      y: mnist.test.labels[:256],
                                      keep_prob: 1.}))
# Out:
# Iter 1280, Minibatch Loss= 20209.218750, Training Accuracy= 0.31250
# Iter 2560, Minibatch Loss= 11950.531250, Training Accuracy= 0.51562
# Iter 3840, Minibatch Loss= 5430.322266, Training Accuracy= 0.74219
# Iter 5120, Minibatch Loss= 5636.918945, Training Accuracy= 0.79688
# Iter 6400, Minibatch Loss= 3638.537109, Training Accuracy= 0.78125
# Iter 7680, Minibatch Loss= 2304.825195, Training Accuracy= 0.87500
# Iter 8960, Minibatch Loss= 1487.648193, Training Accuracy= 0.91406
# Iter 10240, Minibatch Loss= 4766.135254, Training Accuracy= 0.79688
# Iter 11520, Minibatch Loss= 2778.737793, Training Accuracy= 0.85156
# Iter 12800, Minibatch Loss= 2737.419678, Training Accuracy= 0.87500
# Iter 14080, Minibatch Loss= 1533.182983, Training Accuracy= 0.92188
# Iter 15360, Minibatch Loss= 2480.160156, Training Accuracy= 0.87500
# Iter 16640, Minibatch Loss= 2564.351562, Training Accuracy= 0.88281
# Iter 17920, Minibatch Loss= 1767.517944, Training Accuracy= 0.92188
# Iter 19200, Minibatch Loss= 2359.312256, Training Accuracy= 0.85938
# Iter 20480, Minibatch Loss= 1993.269775, Training Accuracy= 0.89062
# Iter 21760, Minibatch Loss= 2408.617920, Training Accuracy= 0.90625
# Iter 23040, Minibatch Loss= 2104.383789, Training Accuracy= 0.91406
# Iter 24320, Minibatch Loss= 991.721802, Training Accuracy= 0.90625
# Iter 25600, Minibatch Loss= 1746.594604, Training Accuracy= 0.93750
# Iter 26880, Minibatch Loss= 747.227478, Training Accuracy= 0.93750
# Iter 28160, Minibatch Loss= 1887.693726, Training Accuracy= 0.90625
# Iter 29440, Minibatch Loss= 1204.150757, Training Accuracy= 0.92969
# Iter 30720, Minibatch Loss= 2526.861572, Training Accuracy= 0.87500
# Iter 32000, Minibatch Loss= 883.287842, Training Accuracy= 0.91406
# Iter 33280, Minibatch Loss= 1647.249756, Training Accuracy= 0.91406
# Iter 34560, Minibatch Loss= 666.557190, Training Accuracy= 0.95312
# Iter 35840, Minibatch Loss= 1260.546387, Training Accuracy= 0.96094
# Iter 37120, Minibatch Loss= 1546.329102, Training Accuracy= 0.92969
# Iter 38400, Minibatch Loss= 1323.908936, Training Accuracy= 0.92969
# Iter 39680, Minibatch Loss= 617.235718, Training Accuracy= 0.96875
# Iter 40960, Minibatch Loss= 1085.364990, Training Accuracy= 0.94531
# Iter 42240, Minibatch Loss= 1135.284302, Training Accuracy= 0.91406
# Iter 43520, Minibatch Loss= 660.283142, Training Accuracy= 0.93750
# Iter 44800, Minibatch Loss= 1179.861816, Training Accuracy= 0.93750
# Iter 46080, Minibatch Loss= 498.224365, Training Accuracy= 0.95312
# Iter 47360, Minibatch Loss= 620.499878, Training Accuracy= 0.94531
# Iter 48640, Minibatch Loss= 677.052246, Training Accuracy= 0.94531
# Iter 49920, Minibatch Loss= 444.711334, Training Accuracy= 0.93750
# Iter 51200, Minibatch Loss= 1171.082520, Training Accuracy= 0.91406
# Iter 52480, Minibatch Loss= 685.251221, Training Accuracy= 0.93750
# Iter 53760, Minibatch Loss= 816.559692, Training Accuracy= 0.94531
# Iter 55040, Minibatch Loss= 989.247375, Training Accuracy= 0.94531
# Iter 56320, Minibatch Loss= 923.509277, Training Accuracy= 0.93750
# Iter 57600, Minibatch Loss= 468.472107, Training Accuracy= 0.96094
# Iter 58880, Minibatch Loss= 882.657715, Training Accuracy= 0.93750
# Iter 60160, Minibatch Loss= 230.695419, Training Accuracy= 0.95312
# Iter 61440, Minibatch Loss= 476.091736, Training Accuracy= 0.96875
# Iter 62720, Minibatch Loss= 1227.068359, Training Accuracy= 0.92969
# Iter 64000, Minibatch Loss= 887.733276, Training Accuracy= 0.96094
# Iter 65280, Minibatch Loss= 1212.159058, Training Accuracy= 0.94531
# Iter 66560, Minibatch Loss= 1044.844604, Training Accuracy= 0.92188
# Iter 67840, Minibatch Loss= 722.070435, Training Accuracy= 0.94531
# Iter 69120, Minibatch Loss= 245.778839, Training Accuracy= 0.96094
# Iter 70400, Minibatch Loss= 1310.469360, Training Accuracy= 0.94531
# Iter 71680, Minibatch Loss= 272.002625, Training Accuracy= 0.97656
# Iter 72960, Minibatch Loss= 423.862488, Training Accuracy= 0.95312
# Iter 74240, Minibatch Loss= 566.368103, Training Accuracy= 0.94531
# Iter 75520, Minibatch Loss= 300.754578, Training Accuracy= 0.96094
# Iter 76800, Minibatch Loss= 447.290009, Training Accuracy= 0.96094
# Iter 78080, Minibatch Loss= 902.550598, Training Accuracy= 0.92969
# Iter 79360, Minibatch Loss= 54.701660, Training Accuracy= 0.99219
# Iter 80640, Minibatch Loss= 676.842224, Training Accuracy= 0.94531
# Iter 81920, Minibatch Loss= 120.688644, Training Accuracy= 0.99219
# Iter 83200, Minibatch Loss= 265.584595, Training Accuracy= 0.96875
# Iter 84480, Minibatch Loss= 979.126221, Training Accuracy= 0.96875
# Iter 85760, Minibatch Loss= 463.523956, Training Accuracy= 0.96875
# Iter 87040, Minibatch Loss= 343.777222, Training Accuracy= 0.97656
# Iter 88320, Minibatch Loss= 502.964172, Training Accuracy= 0.96875
# Iter 89600, Minibatch Loss= 636.115540, Training Accuracy= 0.94531
# Iter 90880, Minibatch Loss= 702.225708, Training Accuracy= 0.96094
# Iter 92160, Minibatch Loss= 103.340088, Training Accuracy= 0.99219
# Iter 93440, Minibatch Loss= 1149.236572, Training Accuracy= 0.92969
# Iter 94720, Minibatch Loss= 481.723999, Training Accuracy= 0.94531
# Iter 96000, Minibatch Loss= 625.691895, Training Accuracy= 0.94531
# Iter 97280, Minibatch Loss= 250.668274, Training Accuracy= 0.96875
# Iter 98560, Minibatch Loss= 462.921021, Training Accuracy= 0.95312
# Iter 99840, Minibatch Loss= 699.687195, Training Accuracy= 0.96094
# Iter 101120, Minibatch Loss= 433.182800, Training Accuracy= 0.94531
# Iter 102400, Minibatch Loss= 392.758057, Training Accuracy= 0.96094
# Iter 103680, Minibatch Loss= 578.486877, Training Accuracy= 0.95312
# Iter 104960, Minibatch Loss= 156.941864, Training Accuracy= 0.97656
# Iter 106240, Minibatch Loss= 193.231033, Training Accuracy= 0.97656
# Iter 107520, Minibatch Loss= 571.838867, Training Accuracy= 0.96094
# Iter 108800, Minibatch Loss= 225.056320, Training Accuracy= 0.96875
# Iter 110080, Minibatch Loss= 90.296860, Training Accuracy= 0.98438
# Iter 111360, Minibatch Loss= 170.464813, Training Accuracy= 0.98438
# Iter 112640, Minibatch Loss= 135.679626, Training Accuracy= 0.96875
# Iter 113920, Minibatch Loss= 388.289246, Training Accuracy= 0.95312
# Iter 115200, Minibatch Loss= 430.746948, Training Accuracy= 0.97656
# Iter 116480, Minibatch Loss= 54.176453, Training Accuracy= 0.98438
# Iter 117760, Minibatch Loss= 568.853699, Training Accuracy= 0.95312
# Iter 119040, Minibatch Loss= 918.000549, Training Accuracy= 0.93750
# Iter 120320, Minibatch Loss= 395.228760, Training Accuracy= 0.97656
# Iter 121600, Minibatch Loss= 657.974548, Training Accuracy= 0.95312
# Iter 122880, Minibatch Loss= 278.696899, Training Accuracy= 0.97656
# Iter 124160, Minibatch Loss= 140.345062, Training Accuracy= 0.98438
# Iter 125440, Minibatch Loss= 388.096283, Training Accuracy= 0.94531
# Iter 126720, Minibatch Loss= 517.889221, Training Accuracy= 0.93750
# Iter 128000, Minibatch Loss= 207.642410, Training Accuracy= 0.96094
# Iter 129280, Minibatch Loss= 163.013397, Training Accuracy= 0.97656
# Iter 130560, Minibatch Loss= 242.559921, Training Accuracy= 0.96094
# Iter 131840, Minibatch Loss= 188.646179, Training Accuracy= 0.96875
# Iter 133120, Minibatch Loss= 147.728989, Training Accuracy= 0.96875
# Iter 134400, Minibatch Loss= 372.229553, Training Accuracy= 0.97656
# Iter 135680, Minibatch Loss= 127.057251, Training Accuracy= 0.99219
# Iter 136960, Minibatch Loss= 83.213654, Training Accuracy= 0.98438
# Iter 138240, Minibatch Loss= 207.330887, Training Accuracy= 0.97656
# Iter 139520, Minibatch Loss= 209.931610, Training Accuracy= 0.96094
# Iter 140800, Minibatch Loss= 212.330017, Training Accuracy= 0.98438
# Iter 142080, Minibatch Loss= 309.484619, Training Accuracy= 0.94531
# Iter 143360, Minibatch Loss= 42.118065, Training Accuracy= 0.97656
# Iter 144640, Minibatch Loss= 115.145607, Training Accuracy= 0.96875
# Iter 145920, Minibatch Loss= 186.031036, Training Accuracy= 0.96875
# Iter 147200, Minibatch Loss= 326.152863, Training Accuracy= 0.92969
# Iter 148480, Minibatch Loss= 115.988693, Training Accuracy= 0.97656
# Iter 149760, Minibatch Loss= 121.047935, Training Accuracy= 0.96875
# Iter 151040, Minibatch Loss= 480.206909, Training Accuracy= 0.92969
# Iter 152320, Minibatch Loss= 429.940857, Training Accuracy= 0.96094
# Iter 153600, Minibatch Loss= 148.224976, Training Accuracy= 0.97656
# Iter 154880, Minibatch Loss= 237.226501, Training Accuracy= 0.97656
# Iter 156160, Minibatch Loss= 169.782837, Training Accuracy= 0.98438
# Iter 157440, Minibatch Loss= 87.402840, Training Accuracy= 0.97656
# Iter 158720, Minibatch Loss= 125.111740, Training Accuracy= 0.96875
# Iter 160000, Minibatch Loss= 118.982117, Training Accuracy= 0.96875
# Iter 161280, Minibatch Loss= 230.027191, Training Accuracy= 0.98438
# Iter 162560, Minibatch Loss= 527.474854, Training Accuracy= 0.95312
# Iter 163840, Minibatch Loss= 393.276825, Training Accuracy= 0.94531
# Iter 165120, Minibatch Loss= 136.472321, Training Accuracy= 0.96875
# Iter 166400, Minibatch Loss= 276.437256, Training Accuracy= 0.96094
# Iter 167680, Minibatch Loss= 64.659714, Training Accuracy= 0.98438
# Iter 168960, Minibatch Loss= 231.590439, Training Accuracy= 0.95312
# Iter 170240, Minibatch Loss= 35.403214, Training Accuracy= 0.97656
# Iter 171520, Minibatch Loss= 220.856659, Training Accuracy= 0.98438
# Iter 172800, Minibatch Loss= 149.962738, Training Accuracy= 0.96875
# Iter 174080, Minibatch Loss= 4.913757, Training Accuracy= 0.99219
# Iter 175360, Minibatch Loss= 77.132416, Training Accuracy= 0.97656
# Iter 176640, Minibatch Loss= 207.911179, Training Accuracy= 0.98438
# Iter 177920, Minibatch Loss= 46.381653, Training Accuracy= 0.99219
# Iter 179200, Minibatch Loss= 70.396027, Training Accuracy= 0.97656
# Iter 180480, Minibatch Loss= 593.320435, Training Accuracy= 0.96875
# Iter 181760, Minibatch Loss= 7.585133, Training Accuracy= 0.98438
# Iter 183040, Minibatch Loss= 116.004089, Training Accuracy= 0.98438
# Iter 184320, Minibatch Loss= 218.043274, Training Accuracy= 0.95312
# Iter 185600, Minibatch Loss= 158.571686, Training Accuracy= 0.97656
# Iter 186880, Minibatch Loss= 335.069641, Training Accuracy= 0.98438
# Iter 188160, Minibatch Loss= 146.515274, Training Accuracy= 0.96875
# Iter 189440, Minibatch Loss= 165.343292, Training Accuracy= 0.98438
# Iter 190720, Minibatch Loss= 146.618362, Training Accuracy= 0.97656
# Iter 192000, Minibatch Loss= 350.371338, Training Accuracy= 0.95312
# Iter 193280, Minibatch Loss= 56.651505, Training Accuracy= 0.98438
# Iter 194560, Minibatch Loss= 547.839600, Training Accuracy= 0.95312
# Iter 195840, Minibatch Loss= 268.746643, Training Accuracy= 0.94531
# Iter 197120, Minibatch Loss= 97.943817, Training Accuracy= 0.98438
# Iter 198400, Minibatch Loss= 2.799973, Training Accuracy= 0.99219
# Iter 199680, Minibatch Loss= 399.564606, Training Accuracy= 0.96875
# Optimization Finished!
# ('Testing Accuracy:', 0.984375)
